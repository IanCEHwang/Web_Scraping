# %%
import requests
import os
import time
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

# %%
class Best_buy_scrap:
    def __init__(self , product_name):
        self.search_term = product_name
        
    ### request search page information and return bs4 object
    def get_search_pages(self , search_term , p_number):
        ### URL
        search_page_url = "https://www.bestbuy.com/site/searchpage.jsp?st="
        ### search product
        search_product = search_term
        
        ### page_number
        page_number = 0
        if p_number == 0:
            page_number = 1
        else:
            page_number = p_number

        ### page_number search term
        search_page_encoding = f"&cp={page_number}"

        ### User agent
        User_Agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36 Edg/88.0.705.56'

        ### request access
        r = requests.get(search_page_url + search_product + search_page_encoding , headers = {'User-Agent' : User_Agent})

        ### Assign bs4 object to soup
        soup = BeautifulSoup(r.content, 'lxml')

        return soup
    
    ### handle price text
    def handle_price(self , price):
        try:
            price = price.replace("$" , "")
            price = float(price)
        except:
            pass
        return price

    ### exrtract brand name from header
    def get_brand(self , header):
        try:
            brand = header.split("-")[0].strip(" ")
        except:
            brand = ""
        return brand
    
    ### get product info from bs4 object and return dict of info
    def get_product_info(self , product):
        return_dict = {}

        ### get header
        header = product.find('h4').text
        return_dict.update({'header' : header})

        ### get brand
        brand = self.get_brand(header)
        return_dict.update({'brand' : brand})

        ### get labels
        try:
            labels = product.find('div' , attrs = {'class' : 'lv-stacked-carousel'}).find_all('button')
            labels = [lab.text for lab in labels]
        except:
            labels = []
        return_dict.update({'labels' : labels})


        ### get model
        model = product.find_all('span' , attrs = {'class' : 'sku-value'})[0].text
        return_dict.update({'model' : model})

        ### get sku
        sku = product.find_all('span' , attrs = {'class' : 'sku-value'})[1].text
        return_dict.update({'sku' : sku})

        ### get stars
        try:
            stars = product.find('p').text.split(' ')[1]
            return_dict.update({'stars' : float(stars)})
        except:
            pass 

        ### get number of reviews
        number_reviews = product.find('p').text.split(' ')[-2]
        return_dict.update({'number_of_reivews' : number_reviews})

        ### get price
        try:
            price = product.find("div" , attrs = {"class" : "priceView-hero-price priceView-customer-price"}).find('span').text
            return_dict.update({"price" : handle_price(price)})
        except:
            pass

        ### get old price
        try:
            old_price = product.find("div" , attrs = {"class" : "pricing-price__regular-price"}).text.split(' ')[1]
            return_dict.update({'original_price' : handle_price(old_price)})
        except:
            pass

        ### price diff
        try:
            reduction = handle_price(old_price) - handle_price(price)
            return_dict.update({'price_reduction' : reduction})
        except:
            pass

        return return_dict
    
    ### execute whole process
    def execute_scrapping(self):
        re_list = []
        stopper = False
        counter = 0

        while stopper != True:
            counter = counter + 1
            page_n = self.get_search_pages(self.search_term , counter)
            page_source = page_n.find_all('div' , attrs = {'class' : 'shop-sku-list-item'})
            
            if len(page_source) == 0:
                stopper = True
            else:
                for product in page_source:
                    re_list.append(self.get_product_info(product))
                print(f"page {counter} done!")
            
            ### pause after request
            time.sleep(5)
        ### return dict of products
        return re_list

# %%
if __name__ == '__main__': 
    
    ### initiate object
    bb_init = Best_buy_scrap("TV")
    
    ### start scrapping
    dict_info = bb_init.execute_scrapping()
# Out:
# page 1 done!
# page 2 done!
# page 3 done!
# page 4 done!
# page 5 done!
# page 6 done!
# page 7 done!
# page 8 done!
# page 9 done!
# page 10 done!
# page 11 done!
# page 12 done!
# page 13 done!
# page 14 done!
# page 15 done!
# page 16 done!
# page 17 done!
# page 18 done!
# page 19 done!
# page 20 done!
# page 21 done!
# page 22 done!
# page 23 done!
# page 24 done!
# page 25 done!
# page 26 done!
# page 27 done!
# page 28 done!

# %%
### check results
dict_info
# Out:
# [{'header': 'Samsung - 65" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN65TU7000FXZA',
#   'sku': '6401722',
#   'stars': 4.6,
#   'number_of_reivews': '12656'},
#  {'header': 'Samsung - 55" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN55TU7000FXZA',
#   'sku': '6401735',
#   'stars': 4.6,
#   'number_of_reivews': '8765'},
#  {'header': 'Insignia™ - 55" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-55F301NA22',
#   'sku': '6450247',
#   'stars': 4.6,
#   'number_of_reivews': '3063'},
#  {'header': 'Samsung - 85" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN85TU7000FXZA',
#   'sku': '6485132',
#   'stars': 4.7,
#   'number_of_reivews': '484'},
#  {'header': 'Samsung - 75" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN75TU7000FXZA',
#   'sku': '6401719',
#   'stars': 4.6,
#   'number_of_reivews': '3188'},
#  {'header': 'Insignia™ - 50" Class F50 Series QLED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-50F501NA22',
#   'sku': '6452313',
#   'stars': 4.4,
#   'number_of_reivews': '451'},
#  {'header': 'Samsung - 43" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN43TU7000FXZA',
#   'sku': '6401740',
#   'stars': 4.6,
#   'number_of_reivews': '9066'},
#  {'header': 'LG - 65" Class C2 Series OLED evo 4K  UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED65C2PUA',
#   'sku': '6501491',
#   'stars': 4.8,
#   'number_of_reivews': '1278'},
#  {'header': 'Insignia™ - 43" Class N10 Series LED Full HD TV',
#   'brand': 'Insignia™',
#   'labels': ['Full HD', 'Direct Lit', 'Non-Smart'],
#   'model': 'NS-43D420NA20',
#   'sku': '6319495',
#   'stars': 4.6,
#   'number_of_reivews': '4209'},
#  {'header': 'Samsung - 70” Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart'],
#   'model': 'UN70TU7000BXZA',
#   'sku': '6429416',
#   'stars': 4.6,
#   'number_of_reivews': '4030'},
#  {'header': 'Samsung - 50" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN50TU7000FXZA',
#   'sku': '6401738',
#   'stars': 4.6,
#   'number_of_reivews': '9363'},
#  {'header': 'Westinghouse - 50" 4K UHD Smart Roku TV with HDR',
#   'brand': 'Westinghouse',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'WR50UX4210',
#   'sku': '6489042',
#   'stars': 4.4,
#   'number_of_reivews': '123'},
#  {'header': 'Sony - 77" Class BRAVIA XR A80K 4K HDR OLED Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'XR77A80K',
#   'sku': '6502608',
#   'stars': 4.8,
#   'number_of_reivews': '540'},
#  {'header': 'LG - 65" Class 83 Series QNED Mini-LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '65QNED83UPA',
#   'sku': '6517099',
#   'stars': 4.7,
#   'number_of_reivews': '131'},
#  {'header': 'LG - 48" Class A2 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED48A2PUA',
#   'sku': '6501902',
#   'stars': 4.7,
#   'number_of_reivews': '801'},
#  {'header': 'Toshiba - 65" Class C350 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '65C350KU',
#   'sku': '6458646',
#   'stars': 4.5,
#   'number_of_reivews': '684'},
#  {'header': 'Insignia™ - 50" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-50F301NA22',
#   'sku': '6456970',
#   'stars': 4.5,
#   'number_of_reivews': '6324'},
#  {'header': 'Samsung - 55” Class Q60B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN55Q60BAFXZA',
#   'sku': '6502243',
#   'stars': 4.8,
#   'number_of_reivews': '347'},
#  {'header': 'Insignia™ - 43" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-43F301NA22',
#   'sku': '6448758',
#   'stars': 4.6,
#   'number_of_reivews': '1949'},
#  {'header': 'Samsung - 85" Class 8000 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN85AU8000FXZA',
#   'sku': '6453026',
#   'stars': 4.7,
#   'number_of_reivews': '319'},
#  {'header': 'LG - 70" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '70NANO75UQA',
#   'sku': '6501916',
#   'stars': 4.2,
#   'number_of_reivews': '139'},
#  {'header': 'Hisense - 40" Class A4G Series LED  Full HD Smart Vidaa TV',
#   'brand': 'Hisense',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '40A4GV',
#   'sku': '6511284',
#   'stars': 4.2,
#   'number_of_reivews': '996'},
#  {'header': 'LG - 55” Class UQ75 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '55UQ7570PUJ',
#   'sku': '6501939',
#   'stars': 4.5,
#   'number_of_reivews': '607'},
#  {'header': 'Samsung - 65" Class 8000 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN65AU8000FXZA',
#   'sku': '6453024',
#   'stars': 4.7,
#   'number_of_reivews': '1982'},
#  {'header': 'Sony - 65" Class BRAVIA XR A80K 4K HDR OLED Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'XR65A80K',
#   'sku': '6502609',
#   'stars': 4.7,
#   'number_of_reivews': '929'},
#  {'header': 'Samsung - 43” Class Q60B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN43Q60BAFXZA',
#   'sku': '6502237',
#   'stars': 4.6,
#   'number_of_reivews': '555'},
#  {'header': 'Sony - 65" Class BRAVIA XR X90K 4K HDR Full Array LED Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'XR65X90K',
#   'sku': '6499801',
#   'stars': 4.6,
#   'number_of_reivews': '637'},
#  {'header': 'Samsung - 85" Class TU690T Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN85TU690TFXZA',
#   'sku': '6527338',
#   'stars': 4.7,
#   'number_of_reivews': '54'},
#  {'header': 'Westinghouse - 32" HD Smart Roku TV',
#   'brand': 'Westinghouse',
#   'labels': ['HD', 'Direct Lit', 'Smart'],
#   'model': 'WR32HX2210',
#   'sku': '6489040',
#   'stars': 4.5,
#   'number_of_reivews': '332'},
#  {'header': 'Sony - 55" Class X75K 4K HDR LED Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'KD55X75K',
#   'sku': '6505137',
#   'stars': 4.6,
#   'number_of_reivews': '351'},
#  {'header': 'Samsung - 65” Class Q80B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN65Q80BAFXZA',
#   'sku': '6503080',
#   'stars': 4.7,
#   'number_of_reivews': '681'},
#  {'header': 'Sony - 75" Class X80K Series LED 4K HDR Smart Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'KD75X80K',
#   'sku': '6499674',
#   'stars': 4.6,
#   'number_of_reivews': '245'},
#  {'header': 'LG - 77" Class A2 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED77A2PUA',
#   'sku': '6501899',
#   'stars': 4.9,
#   'number_of_reivews': '27'},
#  {'header': 'LG - 65” Class UQ75 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '65UQ7570PUJ',
#   'sku': '6501938',
#   'stars': 4.4,
#   'number_of_reivews': '607'},
#  {'header': 'Hisense - 50" Class R6G Series LED 4K UHD Smart Roku TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '50R6G',
#   'sku': '6492216',
#   'stars': 4.6,
#   'number_of_reivews': '359'},
#  {'header': 'Toshiba - 55" Class C350 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '55C350KU',
#   'sku': '6458645',
#   'stars': 4.6,
#   'number_of_reivews': '1166'},
#  {'header': 'Insignia™ - 42" Class F20 Series LED Full HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-42F201NA23',
#   'sku': '6495088',
#   'stars': 4.7,
#   'number_of_reivews': '351'},
#  {'header': 'Insignia™ - 32" Class F20 Series LED HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-32F201NA23',
#   'sku': '6482022',
#   'stars': 4.7,
#   'number_of_reivews': '898'},
#  {'header': 'Insignia™ - 39" Class F20 Series LED HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-39F201NA23',
#   'sku': '6492955',
#   'stars': 4.6,
#   'number_of_reivews': '230'},
#  {'header': 'TCL - 75" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '75S455',
#   'sku': '6500476',
#   'stars': 4.7,
#   'number_of_reivews': '102'},
#  {'header': 'Insignia™ - 65" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-65F301NA23',
#   'sku': '6492966',
#   'stars': 4.5,
#   'number_of_reivews': '257'},
#  {'header': 'Westinghouse - 43" 4K UHD Smart Roku TV with HDR',
#   'brand': 'Westinghouse',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'WR43UX4210',
#   'sku': '6489041',
#   'stars': 4.5,
#   'number_of_reivews': '126'},
#  {'header': 'Samsung - 75" Class 8000 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN75AU8000FXZA',
#   'sku': '6453027',
#   'stars': 4.6,
#   'number_of_reivews': '756'},
#  {'header': 'Hisense - 40" Class A4 Series LED Full HD Smart Android TV',
#   'brand': 'Hisense',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '40A4H',
#   'sku': '6501780',
#   'stars': 4.2,
#   'number_of_reivews': '200'},
#  {'header': 'Sony - 65" Class X75K 4K HDR LED Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'KD65X75K',
#   'sku': '6505136',
#   'stars': 4.6,
#   'number_of_reivews': '414'},
#  {'header': 'LG - 48" Class C2 Series OLED evo 4K  UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED48C2PUA',
#   'sku': '6501499',
#   'stars': 4.8,
#   'number_of_reivews': '340'},
#  {'header': 'Hisense - 55" Class R6G Series LED 4K UHD Smart Roku TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '55R6G',
#   'sku': '6492224',
#   'stars': 4.5,
#   'number_of_reivews': '371'},
#  {'header': 'Sony - 65" Class X80K Series LED 4K HDR Smart Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'KD65X80K',
#   'sku': '6499677',
#   'stars': 4.7,
#   'number_of_reivews': '469'},
#  {'header': 'Insignia™ - 40" Class N10 Series LED Full HD TV',
#   'brand': 'Insignia™',
#   'labels': ['Full HD', 'Direct Lit', 'Non-Smart'],
#   'model': 'NS-40D510NA21',
#   'sku': '6398122',
#   'stars': 4.6,
#   'number_of_reivews': '4046'},
#  {'header': 'Samsung - 55" Class  Q70A Series QLED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN55Q70AAFXZA',
#   'sku': '6452056',
#   'stars': 4.7,
#   'number_of_reivews': '1012'},
#  {'header': 'Hisense - 50" Class A6 Series LED 4K UHD Smart Google TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '50A6H',
#   'sku': '6502592',
#   'stars': 4.5,
#   'number_of_reivews': '290'},
#  {'header': 'Hisense - 65" Class A6 Series LED 4K UHD Smart Google TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '65A6H',
#   'sku': '6502594',
#   'stars': 4.6,
#   'number_of_reivews': '197'},
#  {'header': 'Samsung - 60” Class TU7000 LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart'],
#   'model': 'UN60TU7000FXZA',
#   'sku': '6465636',
#   'stars': 4.6,
#   'number_of_reivews': '801'},
#  {'header': 'Hisense - 75" Class A6 Series LED 4K UHD Smart Google TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '75A6H',
#   'sku': '6502595',
#   'stars': 4.5,
#   'number_of_reivews': '181'},
#  {'header': 'TCL - 65" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '65S455',
#   'sku': '6500473',
#   'stars': 4.6,
#   'number_of_reivews': '536'},
#  {'header': 'Hisense - 85" Class A7 Series LED 4K UHD  Google TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '85A76H',
#   'sku': '6521460',
#   'stars': 4.4,
#   'number_of_reivews': '25'},
#  {'header': 'VIZIO - 40" Class D-Series LED 1080P Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': 'D40f-J09',
#   'sku': '6465459',
#   'stars': 4.3,
#   'number_of_reivews': '1468'},
#  {'header': 'Westinghouse - 43" FHD Smart Roku TV',
#   'brand': 'Westinghouse',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': 'WR43FX2212',
#   'sku': '6489182',
#   'stars': 4.1,
#   'number_of_reivews': '128'},
#  {'header': 'Hisense - 65" Class R6G Series LED 4K UHD Smart Roku TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '65R6G',
#   'sku': '6492222',
#   'stars': 4.6,
#   'number_of_reivews': '350'},
#  {'header': 'Insignia™ - 70" Class F50 Series QLED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-70F501NA22',
#   'sku': '6450253',
#   'stars': 4.6,
#   'number_of_reivews': '173'},
#  {'header': 'LG - 43” Class UQ75 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '43UQ7590PUB',
#   'sku': '6501937',
#   'stars': 4.5,
#   'number_of_reivews': '856'},
#  {'header': 'LG - 50” Class UQ75 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '50UQ7570PUJ',
#   'sku': '6501940',
#   'stars': 4.4,
#   'number_of_reivews': '583'},
#  {'header': 'Insignia™ - 32" Class N10 Series LED HD TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Non-Smart'],
#   'model': 'NS-32D310NA21',
#   'sku': '6395127',
#   'stars': 4.6,
#   'number_of_reivews': '3819'},
#  {'header': 'Samsung - 32" Class Q60A Series  QLED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN32Q60AAFXZA',
#   'sku': '6465202',
#   'stars': 4.6,
#   'number_of_reivews': '695'},
#  {'header': 'Insignia™ - 24" Class N10 Series LED HD TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Non-Smart'],
#   'model': 'NS-24D310NA21',
#   'sku': '6394746',
#   'stars': 4.6,
#   'number_of_reivews': '2364'},
#  {'header': 'Westinghouse - 55" 4K UHD Smart Roku TV with HDR',
#   'brand': 'Westinghouse',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'WR55UX4212',
#   'sku': '6489043',
#   'stars': 3.9,
#   'number_of_reivews': '77'},
#  {'header': 'Westinghouse - 24" HD Smart Roku TV',
#   'brand': 'Westinghouse',
#   'labels': ['HD', 'Direct Lit', 'Smart'],
#   'model': 'WR24HX2210',
#   'sku': '6488966',
#   'stars': 4.5,
#   'number_of_reivews': '386'},
#  {'header': 'Samsung - 32" Class N5300 Series LED Full HD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['Full HD', 'Edge Lit', 'Smart'],
#   'model': 'UN32N5300AFXZA',
#   'sku': '6202106',
#   'stars': 4.6,
#   'number_of_reivews': '7533'},
#  {'header': 'Samsung - 40" Class 5 Series LED Full HD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['Full HD', 'Edge Lit', 'Smart'],
#   'model': 'UN40N5200AFXZA',
#   'sku': '6360291',
#   'stars': 4.7,
#   'number_of_reivews': '8958'},
#  {'header': 'Samsung - 43" Class 8000 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN43AU8000FXZA',
#   'sku': '6452966',
#   'stars': 4.5,
#   'number_of_reivews': '1920'},
#  {'header': 'Hisense - 55" Class A6 Series LED 4K UHD Smart Google TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '55A6H',
#   'sku': '6502593',
#   'stars': 4.3,
#   'number_of_reivews': '201'},
#  {'header': 'Insignia™ - 58" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-58F301NA22',
#   'sku': '6463115',
#   'stars': 4.6,
#   'number_of_reivews': '1127'},
#  {'header': 'TCL - 55" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '55S455',
#   'sku': '6500472',
#   'stars': 4.6,
#   'number_of_reivews': '486'},
#  {'header': 'Insignia™ - 24" Class F20 Series LED Full HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-24F202NA23',
#   'sku': '6490138',
#   'stars': 4.6,
#   'number_of_reivews': '311'},
#  {'header': 'TCL - 65" Class 6-Series Mini-LED QLED 4K UHD Smart Google TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '65R646',
#   'sku': '6470277',
#   'stars': 4.1,
#   'number_of_reivews': '646'},
#  {'header': 'LG - 32" Class LED HD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['HD', 'Direct Lit', 'Smart'],
#   'model': '32LQ630BPUA',
#   'sku': '6501941',
#   'stars': 4.6,
#   'number_of_reivews': '365'},
#  {'header': 'Samsung - 75" Class TU690T Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN75TU690TFXZA',
#   'sku': '6514052',
#   'stars': 4.7,
#   'number_of_reivews': '1502'},
#  {'header': 'Insignia™ - 24" Class F20 Series LED HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-24F201NA23',
#   'sku': '6491295',
#   'stars': 4.7,
#   'number_of_reivews': '808'},
#  {'header': 'TCL - 58" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '58S455',
#   'sku': '6500474',
#   'stars': 4.7,
#   'number_of_reivews': '352'},
#  {'header': 'TCL - 50" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '50S455',
#   'sku': '6500475',
#   'stars': 4.6,
#   'number_of_reivews': '426'},
#  {'header': 'Samsung - 50” Class Q60B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN50Q60BAFXZA',
#   'sku': '6502236',
#   'stars': 4.7,
#   'number_of_reivews': '481'},
#  {'header': 'VIZIO - 32" Class D-Series Full HD Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': 'D32fM-K01',
#   'sku': '6510121',
#   'stars': 4.4,
#   'number_of_reivews': '370'},
#  {'header': 'Samsung - 77" Class S95C OLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'QN77S95CAFXZA',
#   'sku': '6532680',
#   'stars': 4.7,
#   'number_of_reivews': '9'},
#  {'header': 'Toshiba - 43" Class V35 Series LED Full HD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '43V35KU',
#   'sku': '6472249',
#   'stars': 4.6,
#   'number_of_reivews': '473'},
#  {'header': 'Samsung - 55” Class S95B OLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'QN55S95BAFXZA',
#   'sku': '6502216',
#   'stars': 4.6,
#   'number_of_reivews': '425'},
#  {'header': 'LG - 75” Class UP7300PUC LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '75UP7300PUC',
#   'sku': '6517511',
#   'stars': 4.7,
#   'number_of_reivews': '386'},
#  {'header': 'Hisense - 43" Class A6 Series LED 4K UHD Smart Google TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '43A6H',
#   'sku': '6501800',
#   'stars': 4.5,
#   'number_of_reivews': '201'},
#  {'header': 'LG - 55" Class C2 Series OLED evo 4K  UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED55C2PUA',
#   'sku': '6501498',
#   'stars': 4.8,
#   'number_of_reivews': '747'},
#  {'header': 'LG - 42" Class C2 Series OLED evo 4K  UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED42C2PUA',
#   'sku': '6501500',
#   'stars': 4.8,
#   'number_of_reivews': '469'},
#  {'header': 'Toshiba - 32" Class V35 Series LED HD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '32V35KU',
#   'sku': '6472252',
#   'stars': 4.6,
#   'number_of_reivews': '1167'},
#  {'header': 'Samsung - 65” Class QN90B Neo QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN65QN90BAFXZA',
#   'sku': '6500634',
#   'stars': 4.8,
#   'number_of_reivews': '460'},
#  {'header': 'Sony - 55" Class BRAVIA XR A80J Series OLED 4K UHD Smart Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'XR55A80J',
#   'sku': '6455217',
#   'stars': 4.7,
#   'number_of_reivews': '1773'},
#  {'header': 'TCL - 43" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '43S455',
#   'sku': '6500470',
#   'stars': 4.6,
#   'number_of_reivews': '648'},
#  {'header': 'Samsung - 85” Class Q60B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN85Q60BAFXZA',
#   'sku': '6502239',
#   'stars': 4.5,
#   'number_of_reivews': '217'},
#  {'header': 'TCL - 55" Class 4-Series LED 4K UHD Smart Google TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '55S446',
#   'sku': '6470247',
#   'stars': 4.4,
#   'number_of_reivews': '491'},
#  {'header': 'Insignia™ - 65" Class F50 Series QLED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-65F501NA22',
#   'sku': '6450249',
#   'stars': 4.5,
#   'number_of_reivews': '419'},
#  {'header': 'Samsung - 55" Class 8000 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN55AU8000FXZA',
#   'sku': '6452996',
#   'stars': 4.6,
#   'number_of_reivews': '1639'},
#  {'header': 'Insignia™ - 32" Class F20 Series LED  HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-32DF310NA19',
#   'sku': '6247254',
#   'stars': 4.6,
#   'number_of_reivews': '12589'},
#  {'header': 'LG - 65" Class C1 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED65C1PUB',
#   'sku': '6453312',
#   'stars': 4.8,
#   'number_of_reivews': '3771'},
#  {'header': 'Insignia™ - 32" Class F20 Series LED HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-32F201NA22',
#   'sku': '6447531',
#   'stars': 4.5,
#   'number_of_reivews': '1205'},
#  {'header': 'LG - 27" Class LED Full HD Smart TV with webOS',
#   'brand': 'LG',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': '27LQ625S-PU',
#   'sku': '6506780',
#   'stars': 4.5,
#   'number_of_reivews': '273'},
#  {'header': 'Samsung - 32" Class M4500 Series LED HD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['HD', 'Edge Lit', 'Smart'],
#   'model': 'UN32M4500BFXZA',
#   'sku': '6202105',
#   'stars': 4.6,
#   'number_of_reivews': '4525'},
#  {'header': 'Insignia™ - 65" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-65DF710NA21',
#   'sku': '6405232',
#   'stars': 4.5,
#   'number_of_reivews': '1887'},
#  {'header': 'Samsung - 58" Class 7 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN58TU7000FXZA',
#   'sku': '6401726',
#   'stars': 4.4,
#   'number_of_reivews': '2936'},
#  {'header': 'Insignia™ - 39" Class F20 Series LED HD Smart Fire TV Edition TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-39DF310NA21',
#   'sku': '6400439',
#   'stars': 4.5,
#   'number_of_reivews': '3468'},
#  {'header': 'Samsung - 55" Class QN700B Neo QLED 8K Smart TV',
#   'brand': 'Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN55QN700BFXZA',
#   'sku': '6517114',
#   'stars': 4.1,
#   'number_of_reivews': '17'},
#  {'header': 'Insignia™ - 24" Class F20 Series LED HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-24DF310NA21',
#   'sku': '6395125',
#   'stars': 4.5,
#   'number_of_reivews': '4350'},
#  {'header': 'Insignia™ - 24" Class F20 Series LED Full HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-24F202NA22',
#   'sku': '6446230',
#   'stars': 4.4,
#   'number_of_reivews': '918'},
#  {'header': 'Samsung - 43" Class TU690T Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN43TU690TFXZA',
#   'sku': '6514057',
#   'stars': 4.7,
#   'number_of_reivews': '749'},
#  {'header': 'Samsung - 32" Class The Frame QLED Full HD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['Full HD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN32LS03BBFXZA',
#   'sku': '6503092',
#   'stars': 3.6,
#   'number_of_reivews': '15'},
#  {'header': 'Hisense - 43" Class R6G Series LED 4K UHD Smart Roku TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '43R6G',
#   'sku': '6502596',
#   'stars': 4.6,
#   'number_of_reivews': '305'},
#  {'header': 'Sony - 65" Class A8H Series OLED 4K UHD Smart Android TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart'],
#   'model': 'XBR65A8H',
#   'sku': '6401203',
#   'stars': 4.7,
#   'number_of_reivews': '2055'},
#  {'header': 'Westinghouse - 32" HD  TV',
#   'brand': 'Westinghouse',
#   'labels': ['HD', 'Direct Lit', 'Non-Smart'],
#   'model': 'WD32HX1201',
#   'sku': '6532687',
#   'stars': 3.0,
#   'number_of_reivews': '1'},
#  {'header': 'Westinghouse - 65" 4K UHD Smart Roku TV with HDR',
#   'brand': 'Westinghouse',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'WR65UX4210',
#   'sku': '6489044',
#   'stars': 3.5,
#   'number_of_reivews': '78'},
#  {'header': 'Pioneer - 43" Class LED 4K UHD Smart Fire TV',
#   'brand': 'Pioneer',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'PN43951-22U',
#   'sku': '6462309',
#   'stars': 4.6,
#   'number_of_reivews': '665'},
#  {'header': 'Toshiba - 43" Class C350 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '43C350KU',
#   'sku': '6458651',
#   'stars': 4.6,
#   'number_of_reivews': '1032'},
#  {'header': 'Insignia™ - 70" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-70F301NA23',
#   'sku': '6492968',
#   'stars': 4.7,
#   'number_of_reivews': '214'},
#  {'header': 'Pioneer - 55" Class LED 4K UHD Smart Fire TV',
#   'brand': 'Pioneer',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'PN55851-23U',
#   'sku': '6500332',
#   'stars': 4.8,
#   'number_of_reivews': '73'},
#  {'header': 'Toshiba - 50" Class C350 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '50C350KU',
#   'sku': '6458644',
#   'stars': 4.5,
#   'number_of_reivews': '916'},
#  {'header': 'Insignia™ - 75" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-75F301NA22',
#   'sku': '6480926',
#   'stars': 4.5,
#   'number_of_reivews': '334'},
#  {'header': 'LG - 86" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '86NANO75UQA',
#   'sku': '6525091',
#   'stars': 4.4,
#   'number_of_reivews': '18'},
#  {'header': 'LG - 75" Class 83 Series QNED Mini-LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '75QNED83UPA',
#   'sku': '6517096',
#   'stars': 4.7,
#   'number_of_reivews': '73'},
#  {'header': 'LG - 55" Class 80 Series QNED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '55QNED80UQA',
#   'sku': '6501911',
#   'stars': 4.6,
#   'number_of_reivews': '174'},
#  {'header': 'LG - 75" Class 80 Series QNED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '75QNED80UQA',
#   'sku': '6501909',
#   'stars': 4.6,
#   'number_of_reivews': '187'},
#  {'header': 'Sony - 55” Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'XR55A90J',
#   'sku': '6450479',
#   'stars': 4.8,
#   'number_of_reivews': '348'},
#  {'header': 'Samsung - 50" Class 8000 Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN50AU8000FXZA',
#   'sku': '6452997',
#   'stars': 4.6,
#   'number_of_reivews': '1372'},
#  {'header': 'TCL - 85" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '85S455',
#   'sku': '6500477',
#   'stars': 4.7,
#   'number_of_reivews': '40'},
#  {'header': 'Insignia™ - 32" Class F20 Series LED Full HD Smart Fire TV',
#   'brand': 'Insignia™',
#   'labels': ['Full HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-32F202NA23',
#   'sku': '6495086',
#   'stars': 4.6,
#   'number_of_reivews': '190'},
#  {'header': 'LG - 65" Class 80 Series QNED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '65QNED80UQA',
#   'sku': '6501910',
#   'stars': 4.7,
#   'number_of_reivews': '232'},
#  {'header': 'Samsung - 65" Class  Q70A Series QLED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN65Q70AAFXZA',
#   'sku': '6451476',
#   'stars': 4.7,
#   'number_of_reivews': '1312'},
#  {'header': 'LG - 55” Class UQ9000 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '55UQ9000PUD',
#   'sku': '6501928',
#   'stars': 4.6,
#   'number_of_reivews': '291'},
#  {'header': 'LG - 50" Class 80 Series QNED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '50QNED80UQA',
#   'sku': '6501912',
#   'stars': 4.5,
#   'number_of_reivews': '185'},
#  {'header': 'VIZIO - 24" Class D-Series Full HD Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': 'D24f-J09',
#   'sku': '6510151',
#   'stars': 4.1,
#   'number_of_reivews': '116'},
#  {'header': 'LG - 75” Class UQ75 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '75UQ7590PUB',
#   'sku': '6501934',
#   'stars': 4.6,
#   'number_of_reivews': '116'},
#  {'header': 'TCL - 50" Class 4-Series LED 4K UHD Smart Google TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '50S446',
#   'sku': '6470246',
#   'stars': 4.3,
#   'number_of_reivews': '521'},
#  {'header': 'Samsung - 60" Class TU690T Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN60TU690TFXZA',
#   'sku': '6517113',
#   'stars': 4.5,
#   'number_of_reivews': '176'},
#  {'header': 'LG - 50” Class UQ9000 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '50UQ9000PUD',
#   'sku': '6501929',
#   'stars': 4.5,
#   'number_of_reivews': '141'},
#  {'header': 'LG - 43” Class UQ9000 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '43UQ9000PUD',
#   'sku': '6501931',
#   'stars': 4.6,
#   'number_of_reivews': '213'},
#  {'header': 'LG - 86" Class 80 Series QNED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '86QNED80UQA',
#   'sku': '6501908',
#   'stars': 4.7,
#   'number_of_reivews': '69'},
#  {'header': 'VIZIO - 24" Class D-Series LED 720P Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['HD', 'Direct Lit', 'Smart'],
#   'model': 'D24h-J09',
#   'sku': '6523393',
#   'stars': 4.3,
#   'number_of_reivews': '61'},
#  {'header': 'TCL - 55" Class 5-Series QLED 4K UHD Smart Google TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '55S546',
#   'sku': '6470259',
#   'stars': 4.3,
#   'number_of_reivews': '1120'},
#  {'header': 'LG - 70” Class UQ75 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '70UQ7590PUB',
#   'sku': '6501936',
#   'stars': 4.6,
#   'number_of_reivews': '130'},
#  {'header': 'LG - 55" Class B2 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED55B2PUA',
#   'sku': '6501898',
#   'stars': 4.8,
#   'number_of_reivews': '324'},
#  {'header': 'LG - 65” Class UQ9000 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '65UQ9000PUD',
#   'sku': '6501927',
#   'stars': 4.5,
#   'number_of_reivews': '200'},
#  {'header': 'LG - 77" Class C2 Series OLED evo 4K  UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED77C2PUA',
#   'sku': '6501489',
#   'stars': 4.8,
#   'number_of_reivews': '702'},
#  {'header': 'New!Insignia™ - 50" Class F30 Series LED 4K UHD Smart Fire TV',
#   'brand': 'New!Insignia™',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'NS-50F301NA24',
#   'sku': '6525240',
#   'number_of_reivews': 'Yet'},
#  {'header': 'LG - 70” Class UQ9000 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '70UQ9000PUD',
#   'sku': '6501926',
#   'stars': 4.7,
#   'number_of_reivews': '81'},
#  {'header': 'LG - 65" Class A2 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED65A2PUA',
#   'sku': '6501900',
#   'stars': 4.6,
#   'number_of_reivews': '63'},
#  {'header': 'Samsung - 75" Class  Q70A Series QLED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN75Q70AAFXZA',
#   'sku': '6452064',
#   'stars': 4.7,
#   'number_of_reivews': '566'},
#  {'header': 'Samsung - 75" Class QN800 Neo QLED 8K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['8K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN75QN800BFXZA',
#   'sku': '6499306',
#   'stars': 4.7,
#   'number_of_reivews': '66'},
#  {'header': 'Toshiba - 75" Class C350 Series LED 4K UHD Smart Fire TV',
#   'brand': 'Toshiba',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '75C350KU',
#   'sku': '6458648',
#   'stars': 4.6,
#   'number_of_reivews': '424'},
#  {'header': 'Sony - 83" Class A90J Series OLED 4K UHD Smart Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'XR83A90J',
#   'sku': '6456201',
#   'stars': 4.8,
#   'number_of_reivews': '378'},
#  {'header': 'VIZIO - 65" Class V-Series LED 4K UHD Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'V655-J09',
#   'sku': '6459563',
#   'stars': 4.5,
#   'number_of_reivews': '646'},
#  {'header': 'LG - 65" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED65G2PUA',
#   'sku': '6501495',
#   'stars': 4.6,
#   'number_of_reivews': '184'},
#  {'header': 'Samsung - 85" Class QN800 Neo QLED 8K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN85QN800BFXZA',
#   'sku': '6499301',
#   'stars': 4.5,
#   'number_of_reivews': '47'},
#  {'header': 'Sony - 32" Class W830K HD LED Google TV',
#   'brand': 'Sony',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'KD32W830K',
#   'sku': '6505561',
#   'stars': 4.6,
#   'number_of_reivews': '45'},
#  {'header': 'LG - 65" Class B2 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED65B2PUA',
#   'sku': '6501896',
#   'stars': 4.7,
#   'number_of_reivews': '367'},
#  {'header': 'LG - 86" Class 83 Series QNED Mini-LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '86QNED83UPA',
#   'sku': '6517094',
#   'stars': 4.1,
#   'number_of_reivews': '30'},
#  {'header': 'LG - 24” Class LED HD Smart TV with webOS',
#   'brand': 'LG',
#   'labels': ['HD', 'Edge Lit', 'Smart'],
#   'model': '24LQ520S-PU',
#   'sku': '6506779',
#   'stars': 4.6,
#   'number_of_reivews': '95'},
#  {'header': 'Samsung - 85" Class  Q70A Series QLED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN85Q70AAFXZA',
#   'sku': '6452061',
#   'stars': 4.6,
#   'number_of_reivews': '366'},
#  {'header': 'TCL - 55" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart'],
#   'model': '55S555',
#   'sku': '6514544',
#   'stars': 4.4,
#   'number_of_reivews': '199'},
#  {'header': 'VIZIO - 75" Class M6 Series 4K QLED HDR Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'M75Q6-J03',
#   'sku': '6468033',
#   'stars': 4.5,
#   'number_of_reivews': '184'},
#  {'header': 'LG - 77" Class B2 Series OLED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED77B2PUA',
#   'sku': '6501857',
#   'stars': 4.8,
#   'number_of_reivews': '187'},
#  {'header': 'VIZIO - 50" Class V-Series 4K LED HDR Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'V505M-K09',
#   'sku': '6510145',
#   'stars': 4.4,
#   'number_of_reivews': '285'},
#  {'header': 'LG - 43" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '43NANO75UQA',
#   'sku': '6501920',
#   'stars': 4.4,
#   'number_of_reivews': '157'},
#  {'header': 'TCL - 50" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart'],
#   'model': '50S555',
#   'sku': '6514543',
#   'stars': 4.5,
#   'number_of_reivews': '87'},
#  {'header': 'Samsung - 58" Class TU690T Series LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'UN58TU690TFXZA',
#   'sku': '6512703',
#   'stars': 4.6,
#   'number_of_reivews': '440'},
#  {'header': 'TCL - 50" Class 5-Series QLED 4K UHD Smart Google TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '50S546',
#   'sku': '6470258',
#   'stars': 4.2,
#   'number_of_reivews': '279'},
#  {'header': 'LG - 83" Class C2 Series OLED evo 4K  UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED83C2PUA',
#   'sku': '6501488',
#   'stars': 4.7,
#   'number_of_reivews': '105'},
#  {'header': 'VIZIO - 40" Class D-Series Full HD Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': 'D40fM-K09',
#   'sku': '6510122',
#   'stars': 4.5,
#   'number_of_reivews': '67'},
#  {'header': 'TCL - 55" Class 6-Series Mini-LED QLED 4K UHD Smart Google TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '55R646',
#   'sku': '6470273',
#   'stars': 4.0,
#   'number_of_reivews': '529'},
#  {'header': 'Samsung - 65" Class QN800 Neo QLED 8K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['8K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN65QN800BFXZA',
#   'sku': '6499340',
#   'stars': 4.8,
#   'number_of_reivews': '32'},
#  {'header': 'LG - 70” Class UP8070 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '70UP8070PUA',
#   'sku': '6452992',
#   'stars': 4.6,
#   'number_of_reivews': '243'},
#  {'header': 'TCL - 65" Class 5-Series 4K UHD QLED Dolby Vision HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart'],
#   'model': '65S555',
#   'sku': '6514546',
#   'stars': 4.7,
#   'number_of_reivews': '149'},
#  {'header': 'LG - 24” Class LED HD Smart TV with webOS',
#   'brand': 'LG',
#   'labels': ['HD', 'Edge Lit', 'Smart'],
#   'model': '24LQ520S-WU',
#   'sku': '6506778',
#   'stars': 4.6,
#   'number_of_reivews': '66'},
#  {'header': 'Samsung - 85" Class QN90A Neo QLED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN85QN90AAFXZA',
#   'sku': '6451484',
#   'stars': 4.7,
#   'number_of_reivews': '748'},
#  {'header': 'VIZIO - 43" Class V-Series 4K LED HDR Smart TV',
#   'brand': 'VIZIO',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': 'V435M-K04',
#   'sku': '6510144',
#   'stars': 4.6,
#   'number_of_reivews': '144'},
#  {'header': 'TCL - 65" Class 6-Series Mini-LED QLED 8K UHD Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart'],
#   'model': '65R648',
#   'sku': '6470280',
#   'stars': 4.0,
#   'number_of_reivews': '16'},
#  {'header': 'LG - 55" Class 85 Series QNED Mini-LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '55QNED85UQA',
#   'sku': '6501907',
#   'stars': 4.5,
#   'number_of_reivews': '31'},
#  {'header': 'Samsung - 75” Class QN90B Neo QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN75QN90BAFXZA',
#   'sku': '6500633',
#   'stars': 4.8,
#   'number_of_reivews': '305'},
#  {'header': 'Samsung - 86” Class TU9010 LED 4K UHD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'UN86TU9010FXZA',
#   'sku': '6465204',
#   'stars': 4.7,
#   'number_of_reivews': '150'},
#  {'header': 'TCL - 32" Class 3-Series Full HD LED Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['Full HD', 'Direct Lit', 'Smart'],
#   'model': '32S359',
#   'sku': '6508875',
#   'stars': 4.6,
#   'number_of_reivews': '304'},
#  {'header': 'LG - 75" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '75NANO75UQA',
#   'sku': '6501914',
#   'stars': 4.2,
#   'number_of_reivews': '67'},
#  {'header': 'Samsung - 85” Class QN90B Neo QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN85QN90BAFXZA',
#   'sku': '6500631',
#   'stars': 4.7,
#   'number_of_reivews': '173'},
#  {'header': 'Samsung - 55" Class The Frame QLED 4k Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN55LS03BAFXZA',
#   'sku': '6503088',
#   'stars': 4.6,
#   'number_of_reivews': '206'},
#  {'header': 'LG - 75” Class UQ9000 Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '75UQ9000PUD',
#   'sku': '6501925',
#   'stars': 4.7,
#   'number_of_reivews': '107'},
#  {'header': 'SunBriteTV - Veranda 3 Series 55" Class LED Outdoor Full Shade 4K UHD Smart Android TV',
#   'brand': 'SunBriteTV',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'SB-V3-55-4KHDR-BL',
#   'sku': '6501321',
#   'stars': 4.5,
#   'number_of_reivews': '6'},
#  {'header': 'Sony - 43" Class X85K 4K HDR LED Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': 'KD43X85K',
#   'sku': '6501544',
#   'stars': 4.6,
#   'number_of_reivews': '345'},
#  {'header': 'Samsung - 65" Class The Frame QLED 4k Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN65LS03BAFXZA',
#   'sku': '6503087',
#   'stars': 4.6,
#   'number_of_reivews': '195'},
#  {'header': 'Sony - 65” Class BRAVIA XR A90J Series OLED 4K UHD Smart Google TV',
#   'brand': 'Sony',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'XR65A90J',
#   'sku': '6450480',
#   'stars': 4.7,
#   'number_of_reivews': '547'},
#  {'header': 'Samsung - 75” Class Q60B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN75Q60BAFXZA',
#   'sku': '6502241',
#   'stars': 4.7,
#   'number_of_reivews': '381'},
#  {'header': 'Toshiba - 55" Class M550 Series LED 4K UHD Smart Fire TV with hands-free Alexa',
#   'brand': 'Toshiba',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '55M550KU',
#   'sku': '6479694',
#   'stars': 4.3,
#   'number_of_reivews': '310'},
#  {'header': 'Samsung - 50” Class Q80B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN50Q80BAFXZA',
#   'sku': '6503084',
#   'stars': 4.7,
#   'number_of_reivews': '67'},
#  {'header': 'Furrion - Aurora 55" Partial Sun Smart 4K UHD LED Outdoor TV',
#   'brand': 'Furrion',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart'],
#   'model': 'FDUP55CSA',
#   'sku': '6504281',
#   'stars': 4.3,
#   'number_of_reivews': '6'},
#  {'header': 'Samsung - 55” Class QN90B Neo QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN55QN90BAFXZA',
#   'sku': '6500637',
#   'stars': 4.6,
#   'number_of_reivews': '199'},
#  {'header': 'Samsung - 60” Class Q60B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN60Q60BAFXZA',
#   'sku': '6502242',
#   'stars': 4.7,
#   'number_of_reivews': '215'},
#  {'header': 'LG - 55" Class NanoCell 75UQA Series LED 4K UHD Smart webOS TV',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '55NANO75UQA',
#   'sku': '6501918',
#   'stars': 4.4,
#   'number_of_reivews': '109'},
#  {'header': 'Samsung - 75” Class Q80B QLED 4K Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN75Q80BAFXZA',
#   'sku': '6503079',
#   'stars': 4.7,
#   'number_of_reivews': '290'},
#  {'header': 'LG - 77" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED77G2PUA',
#   'sku': '6501483',
#   'stars': 4.7,
#   'number_of_reivews': '192'},
#  {'header': 'LG - 55" Class G2 Series OLED evo 4K UHD Smart webOS TV with Gallery Design',
#   'brand': 'LG',
#   'labels': ['4K UHD', 'Smart', 'Voice Assist'],
#   'model': 'OLED55G2PUA',
#   'sku': '6501487',
#   'stars': 4.8,
#   'number_of_reivews': '63'},
#  {'header': 'TCL - 50" Class 4-Series 4K UHD HDR Smart Roku TV',
#   'brand': 'TCL',
#   'labels': ['4K UHD', 'Direct Lit', 'Smart'],
#   'model': '50S45',
#   'sku': '6514455',
#   'stars': 4.6,
#   'number_of_reivews': '482'},
# ...
#  {'header': 'SunBriteTV - Signature 2 Series 75" Class LED Outdoor Partial Sun 4K UHD TV',
#   'brand': 'SunBriteTV',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'SB-S2-75-4K-BL',
#   'sku': '6377485',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 50" Class QN90C NEO QLED 4K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN50QN90CAFXZA',
#   'sku': '6533839',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Hisense - 75" Class U7G Series Quantum ULED 4K UHD Smart Android TV',
#   'brand': 'Hisense',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '75U7G',
#   'sku': '6457441',
#   'stars': 4.2,
#   'number_of_reivews': '160'},
#  {'header': 'New!Samsung - 75" Class QN800C Neo QLED 8K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN75QN800CFXZA',
#   'sku': '6534227',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura Ultra Bright 86" 4K Ultra HD Outdoor TV',
#   'brand': 'Seura',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'STM3-86-U',
#   'sku': '6458187',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura Ultra Bright 65" 4K Ultra HD Outdoor TV',
#   'brand': 'Seura',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'STM3-65-U',
#   'sku': '6458185',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 43" Class QN90C NEO QLED 4K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN43QN90CAFXZA',
#   'sku': '6533842',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 82" CLASS BE82T-H LED 4K Commercial Grade TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Non-Smart'],
#   'model': 'BE82T-H',
#   'sku': '6462588',
#   'stars': 3.9,
#   'number_of_reivews': '8'},
#  {'header': 'Sony - 75" Class BRAVIA XR Z9K 8K HDR Mini LED Google TV',
#   'brand': 'Sony',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'XR75Z9K',
#   'sku': '6504232',
#   'stars': 5.0,
#   'number_of_reivews': '3'},
#  {'header': 'Samsung - 43" QBB series LED 4K UHD Digital Signage Display - Black',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QB43B',
#   'sku': '6510005',
#   'stars': 5.0,
#   'number_of_reivews': '1'},
#  {'header': 'Seura - Séura 27" Indoor Waterproof TV - Brushed Gold',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'IWT-27-BG',
#   'sku': '6458154',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Indoor Waterproof TV - Black Onyx',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'IWT-19-BL',
#   'sku': '6458146',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Indoor Waterproof TV - Polished Chrome',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'IWT-19-PC',
#   'sku': '6458139',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Indoor Waterproof TV - Brushed Gold',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'IWT-19-BG',
#   'sku': '6458156',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 27" Indoor Waterproof TV - Pearl White',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'IWT-27-WH',
#   'sku': '6458145',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Indoor Waterproof TV - Stainless Steel',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'IWT-19-ST',
#   'sku': '6458149',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 27" Indoor Waterproof TV - Polished Chrome',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'IWT-27-PC',
#   'sku': '6458147',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 27" Indoor Waterproof TV - Stainless Steel',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'IWT-27-ST',
#   'sku': '6458150',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Indoor Waterproof TV - Pearl White',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'IWT-19-WH',
#   'sku': '6458138',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 27" Indoor Waterproof TV - Black Onyx',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'IWT-27-BL',
#   'sku': '6458162',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Sony - 85" Class BRAVIA XR Z9K 8K HDR Mini LED Google TV',
#   'brand': 'Sony',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'XR85Z9K',
#   'sku': '6503451',
#   'stars': 4.3,
#   'number_of_reivews': '8'},
#  {'header': 'New!Roku -  75" Class Plus Series QLED 4K Smart Roku TV',
#   'brand': 'New!Roku',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart'],
#   'model': '75R6A5R',
#   'sku': '6536735',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 50" Class Q60C QLED 4K Smart TV 2023',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN50Q60CAFXZA',
#   'sku': '6537419',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 55" Class Q60C QLED 4K Smart TV 2023',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN55Q60CAFXZA',
#   'sku': '6537379',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 75" CLASS BE75T-H LED 4K Commercial Grade TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Non-Smart'],
#   'model': 'BE75T-H',
#   'sku': '6406418',
#   'stars': 4.7,
#   'number_of_reivews': '3'},
#  {'header': 'New!Samsung - 85" Class QN900C Neo QLED 8K Smart Tizen TV',
#   'brand': 'New!Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN85QN900CFXZA',
#   'sku': '6535208',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 65" Class The Serif QLED 4K Smart TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN65LS01BAFXZA',
#   'sku': '6505534',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 55" Class The Serif QLED 4K Smart TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN55LS01BAFXZA',
#   'sku': '6505535',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 65" CLASS BE65T-H LED 4K Commercial Grade TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Non-Smart'],
#   'model': 'BE65T-H',
#   'sku': '6405702',
#   'stars': 4.2,
#   'number_of_reivews': '6'},
#  {'header': 'Peerless-AV - Neptune™ 75" Shade Series Outdoor 4k UHD TV with included Outdoor Rated Tilt Mount',
#   'brand': 'Peerless',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'ODTV7502',
#   'sku': '6456744',
#   'stars': 4.8,
#   'number_of_reivews': '70'},
#  {'header': 'New!Samsung - 65" Class QN800C Neo QLED 8K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN65QN800CFXZA',
#   'sku': '6534226',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Furrion - Aurora 65" Full Sun Smart 4K LED Outdoor TV',
#   'brand': 'Furrion',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart'],
#   'model': 'FDUB65CSA',
#   'sku': '6504288',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Peerless-AV - 55" Neptune™ Partial Sun 4K HDR Outdoor Smart TV – Comes with FREE Outdoor Tilting Wall Mount',
#   'brand': 'Peerless',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart'],
#   'model': 'ODTV5503',
#   'sku': '6504999',
#   'stars': 4.7,
#   'number_of_reivews': '48'},
#  {'header': 'Peerless-AV - 75" Neptune™ Partial Sun Outdoor 4K HDR Smart TV – Comes with FREE Outdoor Tilting Wall Mount',
#   'brand': 'Peerless',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart'],
#   'model': 'ODTV7503',
#   'sku': '6504998',
#   'stars': 4.8,
#   'number_of_reivews': '5'},
#  {'header': 'Samsung - 70" CLASS BE70T-H LED 4K Commercial Grade TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Direct Lit', 'Non-Smart'],
#   'model': 'BE70T-H',
#   'sku': '6414244',
#   'stars': 3.0,
#   'number_of_reivews': '7'},
#  {'header': 'New!Samsung - 85" Class Q60C QLED 4K Smart TV 2023',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN85Q60CAFXZA',
#   'sku': '6537377',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 70" Class Q60C QLED 4K Smart TV 2023',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN70Q60CAFXZA',
#   'sku': '6537361',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 65" Class Q60C QLED 4K Smart TV 2023',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN65Q60CAFXZA',
#   'sku': '6537375',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 75" Class Q60C QLED 4K Smart TV 2023',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Edge Lit', 'Smart', 'Voice Assist'],
#   'model': 'QN75Q60CAFXZA',
#   'sku': '6537370',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Hisense - 75" Class U800GR 8K ULED Roku TV',
#   'brand': 'Hisense',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': '75U800GR',
#   'sku': '6474601',
#   'stars': 4.3,
#   'number_of_reivews': '20'},
#  {'header': 'Hisense - 32" Class H55 Series LED HD Smart Android TV',
#   'brand': 'Hisense',
#   'labels': ['HD', 'Direct Lit', 'Smart', 'Voice Assist'],
#   'model': '32H5500G',
#   'sku': '6438835',
#   'stars': 3.8,
#   'number_of_reivews': '55'},
#  {'header': 'New!Samsung - 85" Class QN90C NEO QLED 4K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN85QN90CAFXZA',
#   'sku': '6533537',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 65" Class QN90C NEO QLED 4K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN65QN90CAFXZA',
#   'sku': '6533835',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 55" Class QN90C NEO QLED 4K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN55QN90CAFXZA',
#   'sku': '6533836',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 75" Class QN90C NEO QLED 4K Smart TV',
#   'brand': 'New!Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN75QN90CAFXZA',
#   'sku': '6533539',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 65" QMB series LED 4K UHD Digital Signage Display',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Non-Smart'],
#   'model': 'QM65B',
#   'sku': '6500576',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 55" QMB series LED 4K UHD Digital Signage Display',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Non-Smart'],
#   'model': 'QM55B',
#   'sku': '6507915',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 50" QBB series LED 4K UHD Digital Signage Display',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QB50B',
#   'sku': '6496278',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 75" QBB series LED 4K UHD Digital Signage Display',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QB75B',
#   'sku': '6507984',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 50" QMB series LED 4K UHD Digital Signage Display',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QM50B',
#   'sku': '6507914',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 65" QBB series LED 4K UHD Digital Signage Display',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QB65B',
#   'sku': '6505560',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 65" Class QN900C Neo QLED 8K Smart Tizen TV',
#   'brand': 'New!Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN65QN900CFXZA',
#   'sku': '6535209',
#   'number_of_reivews': 'Yet'},
#  {'header': 'New!Samsung - 75" Class QN900C Neo QLED 8K Smart Tizen TV',
#   'brand': 'New!Samsung',
#   'labels': ['8K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN75QN900CFXZA',
#   'sku': '6535210',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Vanity TV Mirror, 24"x36" Mirror',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'SS-2436-19',
#   'sku': '6458197',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Vanity TV Mirror, 33"x36" Mirror',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'SS-3336-19',
#   'sku': '6458192',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 27" Vanity TV Mirror, 45"x36" Mirror',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'SS-4536-27',
#   'sku': '6458194',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 27" Vanity TV Mirror, 33"x36" Mirror',
#   'brand': 'Seura',
#   'labels': ['Full HD', 'Non-Smart'],
#   'model': 'SS-3336-27',
#   'sku': '6458191',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Seura - Séura 19" Vanity TV Mirror, 45"x36" Mirror',
#   'brand': 'Seura',
#   'labels': ['HD', 'Non-Smart'],
#   'model': 'SS-4536-19',
#   'sku': '6458198',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 43" QMB series LED 4K UHD Digital Signage Display - Black',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QM43B',
#   'sku': '6507916',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 55" QBB series LED 4K UHD Digital Signage Display - Black',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QB55B',
#   'sku': '6500044',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Furrion - Aurora 65" Full Shade 4K LED Outdoor TV',
#   'brand': 'Furrion',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'FDUF65CBS',
#   'sku': '6466023',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Furrion - 49" Class LED Outdoor Partial Sun 4K UHD TV',
#   'brand': 'Furrion',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'FDUP49CBR',
#   'sku': '6414922',
#   'stars': 4.2,
#   'number_of_reivews': '5'},
#  {'header': 'Samsung - The Terrace Series 75" Class LED Outdoor Full Sun 4K QLED Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Smart', 'Voice Assist'],
#   'model': 'QN75LST9TAFXZA',
#   'sku': '6462044',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 65" CLASS BH65T Terrace Edition LED Outdoor Partial Sun 4k Commercial Grade TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Non-Smart'],
#   'model': 'BH65T',
#   'sku': '6417392',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 75" CLASS BH75T Terrace Edition LED Outdoor Partial Sun 4k Commercial Grade TV',
#   'brand': 'Samsung',
#   'labels': ['4K UHD', 'Local Dimming', 'Non-Smart'],
#   'model': 'BH75T',
#   'sku': '6417390',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Peerless-AV - Neptune™ 65" Shade Series Outdoor 4k UHD TV with included Outdoor Rated Tilt Mount',
#   'brand': 'Peerless',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'ODTV6502',
#   'sku': '6456743',
#   'stars': 4.8,
#   'number_of_reivews': '143'},
#  {'header': 'Peerless-AV - Neptune™ 55" Shade Series Outdoor 4k UHD TV with included Outdoor Rated Tilt Mount',
#   'brand': 'Peerless',
#   'labels': ['4K UHD', 'Edge Lit', 'Non-Smart'],
#   'model': 'ODTV5502',
#   'sku': '6456741',
#   'stars': 4.8,
#   'number_of_reivews': '82'},
#  {'header': 'Samsung - 43" Class (43" Diag.) - Plasma - 720p - 600Hz - HDTV',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'PN43E450A1FXZA',
#   'sku': '4837604',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 55in FLIP PRO Interactive',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'WM55B',
#   'sku': '6531402',
#   'number_of_reivews': 'Yet'},
#  {'header': 'Samsung - 65in FLIP PRO Interactive',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'WM65B',
#   'sku': '6526062',
#   'number_of_reivews': 'Yet'},
#  {'header': 'LG - StanbyME 27" Class LED Full HD Smart webOS Touch Screen with Portable Design',
#   'brand': 'LG',
#   'labels': ['Full HD', 'Smart'],
#   'model': '27ART10AKPL',
#   'sku': '6525168',
#   'stars': 4.5,
#   'number_of_reivews': '19'},
#  {'header': 'Samsung - 32" Class The Frame Series Full HD Smart Tizen TV',
#   'brand': 'Samsung',
#   'labels': [],
#   'model': 'QN32LS03TBFXZA',
#   'sku': '6405713',
#   'stars': 4.1,
#   'number_of_reivews': '115'}]
